# %% [markdown]
# <a href="https://colab.research.google.com/github/nhuttran1356/Nhan_dien_rac_thai_nhua/blob/main/Nh%E1%BA%ADn_di%E1%BB%87n_r%C3%A1c_th%E1%BA%A3i_nh%E1%BB%B1a.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install -q kaggle

from google.colab import files
files.upload()

# %%
# !mkdir '/content/kaggle.json'
# !cp kaggle.json '/root/.kaggle'
# !chmod 600 /root/.kaggle/kaggle.json

# !kaggle datasets list

# %%
# !kaggle datasets download -d arkadiyhacks/drinking-waste-classification
# Out:
# ...
# 100% 1.49G/1.50G [00:39<00:00, 37.3MB/s]
# 100% 1.50G/1.50G [00:39<00:00, 40.5MB/s]

# %%
# !unzip -q /content/drinking-waste-classification.zip

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 14386, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 14386 (delta 2), reused 4 (delta 2), pack-reused 14379
# Receiving objects: 100% (14386/14386), 13.27 MiB | 38.05 MiB/s, done.
# Resolving deltas: 100% (9953/9953), done.

# %%
# !pip install -r /content/drive/MyDrive/Nhandienchainhua/yolov5/requirements.txt

# %%
# %cd /content/Images_of_Waste/YOLO_imgs
# !mkdir train
# !mkdir train/images
# !mkdir train/labels
# !mv *.jpg train/images
# !mv *.txt train/labels
# Out:
# /content/Images_of_Waste/YOLO_imgs

# %%
# !python /content/drive/MyDrive/Nhandienchainhua/yolov5/train.py --img 640 --batch 24 --epochs 5 --data coco128.yaml --weights /content/drive/MyDrive/Nhandienchainhua/yolov5/runs/train/moi2/weights/last.pt
# Out:
# train: weights=/content/drive/MyDrive/Nhandienchainhua/yolov5/runs/train/moi2/weights/last.pt, cfg=, data=coco128.yaml, hyp=drive/MyDrive/Nhandienchainhua/yolov5/data/hyps/hyp.scratch-low.yaml, epochs=5, batch_size=24, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=drive/MyDrive/Nhandienchainhua/yolov5/runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# Command 'git fetch origin' timed out after 5 seconds
# YOLOv5 🚀 v6.2-205-geef9057 Python-3.7.15 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# ...

# %%
# !python /content/drive/MyDrive/Nhandienchainhua/yolov5/detect.py --source /content/samples.jpg
# Out:
# detect: weights=/content/drive/MyDrive/Nhandienchainhua/yolov5/runs/train/lan3/weights/best.pt, source=/content/samples.jpg, data=drive/MyDrive/Nhandienchainhua/yolov5/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=drive/MyDrive/Nhandienchainhua/yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v6.2-205-geef9057 Python-3.7.15 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7020913 parameters, 0 gradients
# image 1/1 /content/samples.jpg: 288x640 2 AluCans, 3 HDPEMs, 3 PETs, 12.0ms
# Speed: 0.4ms pre-process, 12.0ms inference, 1.4ms NMS per image at shape (1, 3, 640, 640)
# ...

# %%
from IPython.display import Image, display
display(Image(filename= "/content/drive/MyDrive/Nhandienchainhua/yolov5/runs/detect/exp29/Glass673.JPG"))
